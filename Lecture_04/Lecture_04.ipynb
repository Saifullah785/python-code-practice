# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/python-code-practice/blob/main/Lecture_04/Lecture_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dictionary in Python
#
# Dictionaries are used to store data values in key:value pairs.
# they are unordered, mutable, (changeable) and donot allow duplicates keys.
# dict = {
#     "name": "saif",
#     "age": 22,
#     "marks": [90, 80, 70],
# }
# dict['name'],dict['age'],dict['marks']
# dict['key'] = value # to assign or add new

# %%
# This cell initializes a dictionary 'info' and then modifies the value associated with the 'name' key.
info = {
    "name" : "mycollege",
    "subjects" : ["python","C","java"],
    "topics" : ("dict", "set"),

    "age" : 35,
    "is_adult" : True,
    12.99 : 94.4

}
info['name'] = "saif" # overwrite
print(info)
# Out:
# {'name': 'saif', 'subjects': ['python', 'C', 'java'], 'topics': ('dict', 'set'), 'age': 35, 'is_adult': True, 12.99: 94.4}

# %% [markdown]
# # Nested Dictionaries

# %%
# This cell demonstrates a nested dictionary structure and prints the value of the nested 'address' dictionary.
dict = {
    "name": "saif",
    "age": 22,
    "marks": [90, 80, 70],
    "address": {
        "city": "karachi",
        "country": "pakistan"
    }
}

print(dict["address"])
# Out:
# {'city': 'karachi', 'country': 'pakistan'}

# %% [markdown]
# # Dictionary Methods
#
# mydic.keys() # returns a list of all the keys in the dictionary
#
# mydic.values() # returns a list of all the values in the dictionary
#
# mydic.items() # returns a list of tuples, each tuple contains a key-value pair
#
# mydic.get(key) # returns the value for the specified key
#
# mydic.update(key:value) # updates the dictionary with the specified key-value pair

# %%
# This cell initializes a dictionary 'dict' with various key-value pairs, including a nested dictionary for 'address'.
dict = {
    "name": "saif",
    "age": 22,
    "marks": [90, 80, 70],
    "address": {
        "city": "karachi",
        "country": "pakistan"
    }
}

# %% [markdown]
# # Set in Python
# sets are mutable but Each element in the set must be unique & immutable
# Set in the collectin of the unordered items.
#
#
# nums = {1, 2, 3, 4, 5}
# set2 = {1,2,2,2}
#
# # repeated elements stored only once, so it resolved to {1,2}
#
# null_set = set() # empty set syntax

# %%
# This cell demonstrates the creation and behavior of Python sets, including how duplicate elements are handled.
collection = {1, 2, 3, 4, 5}

print(collection)
print(type(collection))


collection = {1, 2,2,3, 3, 4, 5} # set must be unique

print(collection)
print(type(collection))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>
# {1, 2, 3, 4, 5}
# <class 'set'>

# %% [markdown]
# # Set Methods
#
# set.add(el) # adds an element to the set
#
# set.remove(el) # removes the specified element from the set
#
# set.clear() # removes all the elements from the set
#
# set.pop() # removes the last element from the set
#
# set.union(set2) # returns a set containing all the elements from both sets
#
# set.intersection(set2) # returns a set containing the common elements from both sets

# %% [markdown]
# Let's Practice
# 1. Store following word meanings in a python dictionary:
#     table:  "a piece of furniture ", " list of facts & figures"
#     cat : "a small animal"
#
# you are given a list of subjects for students.Assume one classroom is required for 1 subject. How may classrooms are needed by all students.
# "python", "java","c++", "python", "java", "python", "java", "c++", "python", "java", "python", "java", "c++"

# %%
# This cell initializes a set called 'subjects' and prints its contents and type, demonstrating how sets handle duplicate elements.
subjects = {"python", "java","c++", "python", "java", "python", "java", "c++", "python", "java", "python", "java", "c++"}
print(subjects)
print(type(subjects))
# Out:
# {'python', 'c++', 'java'}
# <class 'set'>

# %% [markdown]
# 2. WAP to enter marks of 3 subjects from the user and store them in a dictionary. Start with an empty dictionary & add one by one. USe subject name as key and key & marks as value.
#
#
# figure out a way to store 9&9.0 as separate values in the set.
# (you can take help of built in data types)

# %%
# This cell contains commented-out code that would create a dictionary to store marks for three subjects by taking user input.
# marks = {}
# x = int(input("Enter the phy marks: "))
# marks.update({"phy": x})
# x = int(input("Enter the chem marks: "))
# marks.update({"chem": x})
# x = int(input("Enter the math marks: "))
# marks.update({"math": x})

# print(marks)

# %%
# This cell initializes a set of tuples to store different data types, including float and int representations of the number 9, and then prints the set.
values = {
    ('float', 9.0),
    ('int', 9),
    ('str', 'saif'),
    ('bool', True),

}

print(values)
# Out:
# {('float', 9.0), ('str', 'saif'), ('bool', True), ('int', 9)}
